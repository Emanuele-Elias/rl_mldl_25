# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **comparison of different REINFORCE algorithm**

# %% [markdown]
# REINFORCE vanilla

# %%
csv_path = "vanilla_seed_42_returns.csv"

df = pd.read_csv(csv_path)

window = 100
rolling_mean = df["return"].rolling(window=window).mean()
rolling_std = df["return"].rolling(window=window).std()

plt.figure(figsize=(25, 5))
plt.plot(df["episode"], rolling_mean, label="Moving Average (100)", color="black")

#  ±1 std
plt.fill_between(
    df["episode"],
    rolling_mean - rolling_std,
    rolling_mean + rolling_std,
    alpha=0.2,
    label="±1 Std Dev"
)

plt.xlabel("Episode", fontsize=25)
plt.ylabel("Return", fontsize=25)
plt.tick_params(axis="both", labelsize=22)
plt.title("Training Return with uncertainty band for REINFORCE (vanilla)", fontsize=30)
plt.legend(fontsize=25)
plt.grid(True)
plt.show()

# %%
df = pd.read_csv("REINFORCE_seed_42_test_returns.csv")
df.mean(), df.std()
# Out:
# (return    85.237924
#  dtype: float64,
#  return    28.130465
#  dtype: float64)

# %% [markdown]
# REINFORCE with Baseline AVG

# %%
csv_path = "bavg_seed_42_returns.csv"

df = pd.read_csv(csv_path)

window = 100
rolling_mean = df["return"].rolling(window=window).mean()
rolling_std = df["return"].rolling(window=window).std()

plt.figure(figsize=(25, 5))
plt.plot(df["episode"], rolling_mean, label="Moving Average (100)", color="black")

# ±1 std
plt.fill_between(
    df["episode"],
    rolling_mean - rolling_std,
    rolling_mean + rolling_std,
    alpha=0.2,
    label="±1 Std Dev"
)

plt.xlabel("Episode", fontsize=25)
plt.ylabel("Return", fontsize=25)
plt.tick_params(axis="both", labelsize=22)
plt.title("Training Return with uncertainty band for REINFORCE with baseline AVG", fontsize=30)
plt.legend(fontsize=25)
plt.grid(True)
plt.show()

# %%
df = pd.read_csv("REINFORCE_BAVG_seed_42_test_returns.csv")
df.mean(), df.std()
# Out:
# (return    123.131195
#  dtype: float64,
#  return    20.563007
#  dtype: float64)

# %% [markdown]
# REINFORCE with Baseline Value-Net

# %%
csv_path = "bval_seed_42_returns.csv"

df = pd.read_csv(csv_path)

window = 100
rolling_mean = df["return"].rolling(window=window).mean()
rolling_std = df["return"].rolling(window=window).std()

plt.figure(figsize=(25, 5))
plt.plot(df["episode"], rolling_mean, label="Moving Average (100)", color="black")

#  ±1 std
plt.fill_between(
    df["episode"],
    rolling_mean - rolling_std,
    rolling_mean + rolling_std,
    alpha=0.2,
    label="±1 Std Dev"
)

plt.xlabel("Episode", fontsize=25)
plt.ylabel("Return", fontsize=25)
plt.tick_params(axis="both", labelsize=22)
plt.title("Training Return with uncertainty band for REINFORCE with baseline Value-Net", fontsize=30)
plt.legend(fontsize=25)
plt.grid(True)
plt.show()

# %%
df = pd.read_csv("REINFORCE_BVAL_seed_42_test_returns.csv")
df.mean(), df.std()
# Out:
# (return    226.26962
#  dtype: float64,
#  return    9.421261
#  dtype: float64)

# %% [markdown]
# **Actor-Critic**

# %%
csv_path = "ac_seed_42_returns.csv"

df = pd.read_csv(csv_path)

window = 100
rolling_mean = df["return"].rolling(window=window).mean()
rolling_std = df["return"].rolling(window=window).std()

plt.figure(figsize=(25, 5))
plt.plot(df["episode"], rolling_mean, label="Moving Average (100)", color="black")

#  ±1 std
plt.fill_between(
    df["episode"],
    rolling_mean - rolling_std,
    rolling_mean + rolling_std,
    alpha=0.2,
    label="±1 Std Dev"
)

plt.xlabel("Episode", fontsize=25)
plt.ylabel("Return", fontsize=25)
plt.tick_params(axis="both", labelsize=22)
plt.title("Training Return with uncertainty band for Actor-Critic",fontsize=30)
plt.legend(fontsize=25)
plt.grid(True)
plt.show()

# %%
df = pd.read_csv("ActorCritic_seed_42_test_returns.csv")
df.mean(), df.std()
# Out:
# (return    198.152347
#  dtype: float64,
#  return    7.960681
#  dtype: float64)

# %% [markdown]
# **PPO**

# %%
csv_path = "ppo_source_seed_42_UDR_False_returns.csv"

df = pd.read_csv(csv_path)

window = 100
rolling_mean = df["return"].rolling(window=window).mean()
rolling_std = df["return"].rolling(window=window).std()

plt.figure(figsize=(25, 5))
plt.plot(df["episode"], rolling_mean, label="Moving Average (100)", color="black")

#  ±1 std
plt.fill_between(
    df["episode"],
    rolling_mean - rolling_std,
    rolling_mean + rolling_std,
    alpha=0.2,
    label="±1 Std Dev"
)

plt.xlabel("Episode", fontsize=25)
plt.ylabel("Return", fontsize=25)
plt.tick_params(axis="both", labelsize=22)
plt.title("Training Return with uncertainty band for PPO (without tuning and UDR)",fontsize=30)
plt.legend(fontsize=25)
plt.grid(True)
plt.show()

# %% [markdown]
# **Comparison REINFORCE-ActorCritic-PPO**

# %%
window   = 100         
max_ep   = 7000        
csv_bval   = "bval_seed_42_returns.csv"
csv_ppo  = "ppo_source_seed_42_UDR_False_returns.csv"
csv_v = "vanilla_seed_42_returns.csv"
csv_bavg = "bavg_seed_42_returns.csv"
csv_ac = "ac_seed_42_returns.csv"

bval = pd.read_csv(csv_bval)
bval = bval[bval["episode"] <= max_ep]                      # taglia a 6000 episodi
bval["ma"] = bval["return"].rolling(window).mean()        # moving-average

ppo = pd.read_csv(csv_ppo)
ppo = ppo[ppo["episode"] <= max_ep]
ppo["ma"] = ppo["return"].rolling(window).mean()

v = pd.read_csv(csv_v)
v = v[v["episode"] <= max_ep]
v["ma"] = v["return"].rolling(window).mean()

bavg = pd.read_csv(csv_bavg)
bavg = bavg[bavg["episode"] <= max_ep]
bavg["ma"] = bavg["return"].rolling(window).mean()

ac = pd.read_csv(csv_ac)
ac = ac[ac["episode"] <= max_ep]
ac["ma"] = ac["return"].rolling(window).mean()

plt.figure(figsize=(25, 5))

plt.plot(v["episode"], v["ma"], label="REINFORCE (vanilla)",                color="red")
plt.plot(bavg["episode"], bavg["ma"], label="REINFORCE with baseline AVG",                color="orange")
plt.plot(bval["episode"],  bval["ma"],  label="REINFORCE with baseline Value-Net", color="royalblue")
plt.plot(ac["episode"],  ac["ma"],  label="Actor-Critic", color="green")
plt.plot(ppo["episode"], ppo["ma"], label="PPO (without tuning and UDR)",                color="purple")


plt.xlabel("Episode", fontsize=25)
plt.ylabel("Return", fontsize=25)
plt.tick_params(axis="both", labelsize=22)
plt.title(f"Comparison of moving-average ({window}) of returns for the first {max_ep} episodes",fontsize=30)
plt.legend(fontsize=25)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Comparison PPO with UDR and without**

# %% [markdown]
# Best parameters found for PPO:
#
#     gamma          : 0.99
#     learning_rate  : 3e-4
#
# Best parameters found for UDR:
#
#     body 2: [0.90, 1.10]
#     body 3: [0.90, 1.10]
#     body 4: [0.50, 1.50]

# %%
csv_path = "ppo_tuned_source_seed_42_UDR_False_returns.csv"

df = pd.read_csv(csv_path)

window = 100
rolling_mean = df["return"].rolling(window=window).mean()
rolling_std = df["return"].rolling(window=window).std()

plt.figure(figsize=(25, 5))
plt.plot(df["episode"], rolling_mean, label="Moving Average (100)", color="black")

#  ±1 std
plt.fill_between(
    df["episode"],
    rolling_mean - rolling_std,
    rolling_mean + rolling_std,
    alpha=0.2,
    label="±1 Std Dev"
)

plt.xlabel("Episode", fontsize=25)
plt.ylabel("Return", fontsize=25)
plt.tick_params(axis="both", labelsize=22)
plt.title("Training Return with uncertainty band for PPO (with tuning but without UDR)",fontsize=30)
plt.legend(fontsize=25)
plt.grid(True)
plt.show()

# %%
csv_path = "ppo_tuned_target_seed_42_UDR_False_returns.csv"

df = pd.read_csv(csv_path)

window = 100
rolling_mean = df["return"].rolling(window=window).mean()
rolling_std = df["return"].rolling(window=window).std()

plt.figure(figsize=(25, 5))
plt.plot(df["episode"], rolling_mean, label="Moving Average (100)", color="black")

#  ±1 std
plt.fill_between(
    df["episode"],
    rolling_mean - rolling_std,
    rolling_mean + rolling_std,
    alpha=0.2,
    label="±1 Std Dev"
)
plt.xlabel("Episode", fontsize=25)
plt.ylabel("Return", fontsize=25)
plt.tick_params(axis="both", labelsize=22)
plt.title("Training Return with uncertainty band for PPO (with tuning but without UDR) on target environment",fontsize=30)
plt.legend(fontsize=25)
plt.grid(True)
plt.show()

# %%
csv_path = "ppo_tuned_source_seed_42_UDR_True_returns.csv"

df = pd.read_csv(csv_path)

window = 100
rolling_mean = df["return"].rolling(window=window).mean()
rolling_std = df["return"].rolling(window=window).std()

plt.figure(figsize=(25, 5))
plt.plot(df["episode"], rolling_mean, label="Moving Average (100)", color="black")

#  ±1 std
plt.fill_between(
    df["episode"],
    rolling_mean - rolling_std,
    rolling_mean + rolling_std,
    alpha=0.2,
    label="±1 Std Dev"
)

plt.xlabel("Episode", fontsize=25)
plt.ylabel("Return", fontsize=25)
plt.tick_params(axis="both", labelsize=22)
plt.title("Training Return with uncertainty band for PPO (with tuning and UDR)", fontsize=30)
plt.legend(fontsize=25)
plt.grid(True)
plt.show()

# %%
window      = 100
max_ep      = 5600
csv_default = "ppo_source_seed_42_UDR_False_returns.csv"
csv_tuned_s = "ppo_tuned_source_seed_42_UDR_False_returns.csv"
csv_tuned_u = "ppo_tuned_source_seed_42_UDR_True_returns.csv"
csv_tuned_t = "ppo_tuned_target_seed_42_UDR_False_returns.csv"
# ----------------------------------------

def load_and_roll(csv):
    df        = pd.read_csv(csv)
    df        = df[df["episode"] <= max_ep]
    df["ma"]  = df["return"].rolling(window).mean()
    df["std"] = df["return"].rolling(window).std()
    return df

df_def  = load_and_roll(csv_default)
df_tsrc = load_and_roll(csv_tuned_s)
df_tudr = load_and_roll(csv_tuned_u)
df_ttar = load_and_roll(csv_tuned_t)


plt.figure(figsize=(25, 5))

# PPO default (source)
plt.plot(df_def["episode"], df_def["ma"],
         label="PPO default (source)", color="royalblue")


# PPO tuned (source)
plt.plot(df_tsrc["episode"], df_tsrc["ma"],
         label="PPO tuned (source)", color="black")


# PPO tuned + UDR (source)
plt.plot(df_tudr["episode"], df_tudr["ma"],
         label="PPO tuned + UDR (source)", color="forestgreen")


# PPO tuned (target) 
plt.plot(df_ttar["episode"], df_ttar["ma"],
         label="PPO tuned (target)", color="firebrick", linewidth=2.0)

# plot
plt.xlabel("Episode", fontsize=25)
plt.ylabel("Return", fontsize=25)
plt.tick_params(axis="both", labelsize=22)
plt.title(f"first {max_ep} episodes · Moving-Average {window} comparison", fontsize=30)
plt.legend(fontsize=25)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Extension**

# %%
from pathlib import Path

metrics     = ["score1", "score2", "score3"]      
optimizers  = ["cma", "pso", "de"]                
window      = 100                           
csv_pattern = "ppo_tuned_source_seed_42_simopt_{metric}_{optimizer}_returns.csv"
# -----------------------------------------------------------------------------


for metric in metrics:
    for opt in optimizers:

        csv_path = csv_pattern.format(metric=metric, optimizer=opt)
        if not Path(csv_path).is_file():
            print(f"[WARN] File mancante, salto: {csv_path}")
            continue

        df = pd.read_csv(csv_path)

        rolling_mean = df["return"].rolling(window=window).mean()
        rolling_std  = df["return"].rolling(window=window).std()

        plt.figure(figsize=(25, 5))
        plt.plot(df["episode"], rolling_mean,
                 label=f"Moving Average ({window})", color="black")

        # fascia ±1 σ
        plt.fill_between(df["episode"],
                         rolling_mean - rolling_std,
                         rolling_mean + rolling_std,
                         alpha=0.2, label="±1 Std Dev")

        plt.xlabel("Episode", fontsize=25)
        plt.ylabel("Return", fontsize=25)
        plt.tick_params(axis="both", labelsize=22)
        plt.title(f"Training Return with uncertainty band for PPO simopt\noptimizer={opt.upper()}, metric={metric}", fontsize=30)
        plt.legend(fontsize=25)
        plt.grid(True)
        plt.show()

# %%
import itertools 

metrics     = ["score1", "score2", "score3"]
optimizers  = ["cma", "pso", "de"]
window      = 100
csv_pattern = "ppo_tuned_source_seed_42_simopt_{metric}_{optimizer}_returns.csv"
# ------------------------------------------------------------------------------

plt.figure(figsize=(25, 5))
color_cycle = itertools.cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])

for metric in metrics:
    for opt in optimizers:

        csv_path = csv_pattern.format(metric=metric, optimizer=opt)
        if not Path(csv_path).is_file():
            print(f"[WARN] File mancante, salto: {csv_path}")
            continue

        df = pd.read_csv(csv_path)

        rolling = (
            df["return"]
            .rolling(window=window, min_periods=1)  
            .mean()
        )

        plt.plot(
            df["episode"],
            rolling,
            label=f"{metric}-{opt}",
            color=next(color_cycle),
            linewidth=1.8
        )

plt.xlabel("Episode", fontsize=25)
plt.ylabel("Return", fontsize=25)
plt.tick_params(axis="both", labelsize=22)
plt.title(f"PPO simopt — Moving Average ({window}) di tutti i run", fontsize=30)
plt.legend(ncol=3, fontsize=25)                 
plt.grid()
plt.tight_layout()
plt.show()
